# %% [markdown]
# ## LV 09 Psihofiziološki signali
#
# ### 2. WESAD baza Pregled signalov

# %%
#  !pip install numpy
#  !pip install pandas

# %%
import pickle
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
pickle.HIGHEST_PROTOCOL
# Out:
# 5

# %%
# P.1
# Nastavi pot do podatkov
#data_set = r'D:\\J_PROG_DATA\\2024_UPK_WESAD\\WESAD\\'
#data_set = r'D:\\J_PROG_DATA\\WESAD\\'
data_set = r'C:\\_DATA\\WESAD\\'
s2_path = data_set + 'S2/S2.pkl'

# P.1 : Nalaganje podatkov ene osebe
with open(s2_path, 'rb') as file:
    s2_data = pickle.load(file, encoding='latin1')
# Out:
# C:\Users\janezzaletelj\AppData\Local\Temp\ipykernel_5228\1425746788.py:10: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   s2_data = pickle.load(file, encoding='latin1')

# %%
# P.2 : Struktura podatkov ene osebe
# Izberi podatke osebe kot data
data = s2_data


# Izpiši podatke:
print(data)

# Izpiši podatke : ključi
print(data.keys())

# Subject
print('Subject: ', data['subject'])

# Labels
print('Labele: ', data['label'], data['label'].shape)

# Signals
print('signali: ', data['signal'])

# Uporabi za signal: .dtype,  .shape, .size, .ndim
print('ACC Data: ', data['signal']['chest']['ACC'].dtype)
print('ACC Data: ', data['signal']['chest']['ACC'].shape)

print('ACC Data: ', data['signal']['chest']['EMG'].dtype)
print('ACC Data: ', data['signal']['chest']['EMG'].shape)

print('ECG: ', data['signal']['chest']['ECG'].dtype)
print('ECG: ', data['signal']['chest']['ECG'].shape)
# Out:
# {'signal': {'chest': {'ACC': array([[ 0.95539999, -0.222     , -0.55799997],
#        [ 0.92579997, -0.2216    , -0.55379999],
#        [ 0.90820003, -0.21960002, -0.53920001],
#        ...,
#        [ 0.87179995, -0.12379998, -0.30419999],
#        [ 0.87300003, -0.12339997, -0.30260003],
#        [ 0.87020004, -0.12199998, -0.30220002]], shape=(4255300, 3)), 'ECG': array([[ 0.02142334],
#        [ 0.02032471],
#        [ 0.01652527],
#        ...,
#        [-0.00544739],
#        [ 0.00013733],
#        [ 0.0040741 ]], shape=(4255300, 1)), 'EMG': array([[-0.00444031],
#        [ 0.00434875],
#        [ 0.00517273],
#        ...,
#        [-0.01716614],
#        [-0.02897644],
#        [-0.02357483]], shape=(4255300, 1)), 'EDA': array([[5.25054932],
#        [5.26733398],
#        [5.24330139],
#        ...,
#        [0.36048889],
#        [0.36582947],
#        [0.365448  ]], shape=(4255300, 1)), 'Temp': array([[30.120758],
#        [30.129517],
#        [30.138214],
#        ...,
# ...

# %%
# P.3: Labele: stanja osebe
count=len(data['label'])
print('Stevilo vzorcev  = ', count)

sample_n = np.arange(1,count+1)
print(sample_n)

# Komentar
d_label = pd.DataFrame(data['label'], columns=['label'])
d_label['sec']=d_label['label']
d_label['sec']=sample_n/700
print(d_label)

# Možne vrednosti label:
print('Možne vrednosti label: ', d_label['label'].unique())

# Histogram label
d_label['label'].hist()
d_label.plot(x='sec', y='label')
# Out:
# Stevilo vzorcev  =  4255300
# [      1       2       3 ... 4255298 4255299 4255300]
#          label          sec
# 0            0     0.001429
# 1            0     0.002857
# 2            0     0.004286
# 3            0     0.005714
# 4            0     0.007143
# ...        ...          ...
# 4255295      0  6078.994286
# 4255296      0  6078.995714
# 4255297      0  6078.997143
# 4255298      0  6078.998571
# 4255299      0  6079.000000
#
# [4255300 rows x 2 columns]
# Možne vrednosti label:  [0 1 2 6 4 3 7]
# <Axes: xlabel='sec'>

# %%
# P.4: Podatki po senzorjih

c_ax=data['signal']['chest']['ACC'][0:,0]
c_ay=data['signal']['chest']['ACC'][0:,1]
c_az=data['signal']['chest']['ACC'][0:,2]
c_ecg=data['signal']['chest']['ECG'][:,0]
c_emg=data['signal']['chest']['EMG'][:,0]
c_eda=data['signal']['chest']['EDA'][:,0]
c_temp=data['signal']['chest']['Temp'][:,0]
c_resp=data['signal']['chest']['Resp'][:,0]
w_ax=data['signal']['wrist']['ACC'][0:,0]
w_ay=data['signal']['wrist']['ACC'][0:,1]
w_az=data['signal']['wrist']['ACC'][0:,2]
w_bvp=data['signal']['wrist']['BVP'][:,0]
w_eda=data['signal']['wrist']['EDA'][:,0]
w_temp=data['signal']['wrist']['TEMP'][:,0]
c_label=data['label']

# %%
baseline_indices = np.nonzero(data['label']==1)[0]
stress_indices = np.nonzero(data['label']==2)[0]
amusement_indices = np.nonzero(data['label']==3)[0]
meditation_indices = np.nonzero(data['label']==4)[0]

print("baseline_indices", len(baseline_indices), len(baseline_indices)/700)
print("stress_indices", len(stress_indices), len(stress_indices)/700)
print("amusement_indices", len(amusement_indices), len(amusement_indices)/700)
print("meditation_indices", len(meditation_indices), len(meditation_indices)/700)

# Število sekund za stanja osebe ?
fig = plt.figure()
ax = fig.add_axes([0.1,0.1,1,1])
langs = ["baseline", "stress", "amusement","meditation"]
y_ax = [len(baseline_indices),len(stress_indices),len(amusement_indices),len(meditation_indices)]
ax.bar(langs,y_ax,color = 'b', width = 0.45)
# Out:
# baseline_indices 800800 1144.0
# stress_indices 430500 615.0
# amusement_indices 253400 362.0
# meditation_indices 537599 767.9985714285714
# <BarContainer object of 4 artists>

# %%
# P.6 : Naredimo DataFrame z vsemi signali (Chest)

numpy_data1=np.array([sample_n/700, c_ax, c_ay, c_az,c_ecg,c_emg,c_eda,c_temp,c_resp,c_label])
numpy_data1=numpy_data1.T

# Chest signali
dfc = pd.DataFrame(data=numpy_data1, columns=["sec","c_ax", "c_ay", "c_az","c_ecg","c_emg","c_eda","c_temp","c_resp","c_label"]) 

print("data frame combined")
print(dfc.head())
dfc.info()
# Out:
# data frame combined
#         sec    c_ax    c_ay    c_az     c_ecg     c_emg     c_eda     c_temp  \
# 0  0.001429  0.9554 -0.2220 -0.5580  0.021423 -0.004440  5.250549  30.120758
# 1  0.002857  0.9258 -0.2216 -0.5538  0.020325  0.004349  5.267334  30.129517
# 2  0.004286  0.9082 -0.2196 -0.5392  0.016525  0.005173  5.243301  30.138214
# 3  0.005714  0.8974 -0.2102 -0.5122  0.016708  0.007187  5.249405  30.129517
# 4  0.007143  0.8882 -0.2036 -0.4824  0.011673 -0.015152  5.286407  30.130951
#
#      c_resp  c_label
# 0 -1.148987      0.0
# 1 -1.124573      0.0
# 2 -1.152039      0.0
# 3 -1.158142      0.0
# 4 -1.161194      0.0
# <class 'pandas.DataFrame'>
# RangeIndex: 4255300 entries, 0 to 4255299
# Data columns (total 10 columns):
#  #   Column   Dtype
# ---  ------   -----
#  0   sec      float64
#  1   c_ax     float64
#  2   c_ay     float64
#  3   c_az     float64
#  4   c_ecg    float64
#  5   c_emg    float64
#  6   c_eda    float64
#  7   c_temp   float64
# ...

# %%
# P.7 Statistika vrednosti
dfc.describe()
# Out:
#                 sec          c_ax          c_ay          c_az         c_ecg  \
# count  4.255300e+06  4.255300e+06  4.255300e+06  4.255300e+06  4.255300e+06
# mean   3.039501e+03  7.538656e-01 -1.331884e-01 -4.226812e-01  1.212245e-03
# std    1.754856e+03  1.751162e-01  6.417297e-02  3.002357e-01  1.540773e-01
# min    1.428571e-03  2.150000e-01 -6.600000e-01 -1.135400e+00 -1.499542e+00
# 25%    1.519751e+03  6.210001e-01 -1.498000e-01 -7.172000e-01 -6.797791e-02
# 50%    3.039501e+03  8.568000e-01 -1.256000e-01 -3.222000e-01  8.239746e-03
# 75%    4.559250e+03  8.922000e-01 -9.579998e-02 -2.098000e-01  4.435730e-02
# max    6.079000e+03  2.029800e+00  5.390000e-01  1.246800e+00  1.499313e+00
#
#               c_emg         c_eda        c_temp        c_resp       c_label
# count  4.255300e+06  4.255300e+06  4.255300e+06  4.255300e+06  4.255300e+06
# mean  -2.412918e-03  1.528387e+00  3.087668e+01  5.490614e-02  1.212370e+00
# ...

# %%
# P.8 Histogrami vrednosti
print(dfc.columns)

dfc.hist(column=['c_ax','c_ay','c_az'], bins=50, figsize=(10,6))
# Out:
# Index(['sec', 'c_ax', 'c_ay', 'c_az', 'c_ecg', 'c_emg', 'c_eda', 'c_temp',
#        'c_resp', 'c_label'],
#       dtype='str')
# array([[<Axes: title={'center': 'c_ax'}>,
#         <Axes: title={'center': 'c_ay'}>],
#        [<Axes: title={'center': 'c_az'}>, <Axes: >]], dtype=object)

# %%
# Dataframe po stanjih
dfc_base = dfc.loc[(dfc['c_label'] == 1)]
dfc_stress = dfc.loc[(dfc['c_label'] == 2)]
dfc_amus = dfc.loc[(dfc['c_label'] == 3)]
dfc_medi = dfc.loc[(dfc['c_label'] == 4)]

print("Baseline samples: ", dfc_base.shape)
print("Stress samples: ", dfc_stress.shape)
# Out:
# Baseline samples:  (800800, 10)
# Stress samples:  (430500, 10)

# %%
ind_b = dfc['c_label']==1
ind_s = dfc['c_label']==2
ind_base_stress =  (dfc['c_label']==1) | (dfc['c_label']==2)

# Dataframe baseline, stres
dfc_base_str = dfc.loc[ind_base_stress]
print(dfc_base_str.shape)
# Out:
# (1231300, 10)

# %%
# P.10 Izris signalov

# Izberemo del signala za izris, v sekundah
t_start = 1
t_length = 50
tip = 'c_resp'



sample_beg = t_start * 700
sample_length = t_length * 700
sample_end = sample_beg + sample_length


y_ax =  dfc_base[tip].iloc[sample_beg:sample_end].values
y_ax_s= dfc_stress[tip].iloc[sample_beg:sample_end].values
y_ax_a= dfc_amus[tip].iloc[sample_beg:sample_end].values
y_ax_m= dfc_medi[tip].iloc[sample_beg:sample_end].values

x_ax=np.arange(len(y_ax))

fig= plt.figure(figsize=(6,3))
ax1= fig.add_axes([0.1,0.1,2,2])
#fig1, ax1 = plt.subplots()
ax1.plot(x_ax,y_ax,color='green',label=tip + " base")
ax1.plot(x_ax,y_ax_s,color='red',label=tip + " stress")
ax1.plot(x_ax,y_ax_a,color='blue',label=tip + " amusement")
ax1.plot(x_ax,y_ax_m,color='black',label=tip + " meditation")
ax1.set(xlabel='number of samples', ylabel = 'sensor amplitude', title = tip + ' base vs stress vs amusement vs meditation')
ax1.grid()
plt.legend(loc='upper left')
plt.show()

# %%
# P.11 Histogrami vrednosti signalov

import seaborn as sns

stolpci = ['c_ax', 'c_ay', 'c_az', 'c_ecg', 'c_emg', 'c_eda', 'c_temp',
       'c_resp']

for col in dfc_base_str[stolpci]:
    fg = sns.FacetGrid(dfc_base_str, hue="c_label", aspect=5, legend_out=True)
    fg.map(sns.histplot, col, fill=True)
plt.show()

# %%
from scipy.signal import find_peaks
from scipy.signal import savgol_filter
from scipy import signal

def decompose_eda(eda):
    scr_list  = []
    b,a = signal.butter(4,0.5/2)
    gsr_filt = signal.filtfilt(b,a,eda,axis=0)
    b,a = signal.butter(4,0.5/2,'highpass')
    scr = signal.filtfilt(b,a,gsr_filt,axis=0)
    scl = [float(x[0]-y[0]) for x,y in zip(gsr_filt,scr)]
    for i in range(len(scr)):
        scr_list.append(scr[i][0])
    return scr_list,scl

# %%
eda_scr, eda_scl = decompose_eda(data['signal']['chest']['EDA'])

# %%
# Izris EDA signalov

starts = 0
nsamples = 500

x = np.arange(len(data['signal']['chest']['ECG'][0:nsamples]))*1/700

plt.figure(figsize=(30,20))
plt.subplot(2, 1, 1)
plt.title('Figure 1. Extraction SCR and SCL from EDA Raw Data', fontsize = 30)
plt.grid(True)

plt.plot(x, data['signal']['chest']['EDA'][0:nsamples], color = 'black', lw = 4, label = 'EDA Raw Data')
plt.plot(x, eda_scl[0:nsamples], color = 'red', lw = 4, label = 'SCL Data')

plt.yticks(fontsize=20)
plt.xticks(fontsize=20)
plt.ylabel('µS', fontsize = 25)
plt.xlabel('Time, seconds', fontsize = 25)
plt.legend(prop={'size': 30})
plt.subplot(2, 1, 2)
plt.plot(x, eda_scr[0:nsamples], color = 'green', lw = 3, label = 'SCR Data')
plt.grid(True)
plt.yticks(fontsize=20)
plt.xticks(fontsize=20)
plt.xlabel('Time, seconds', fontsize = 25)
plt.ylabel('Hz', fontsize = 25)
plt.legend(prop={'size': 30})
plt.show()

# %%
# SCR PEAK DETECTION

scr_chest = eda_scr

plt.figure(figsize=(30,20))
plt.subplot(2, 1, 1)
plt.title('Figure 2. SCR Data peak detection.', fontsize = 30)
plt.grid(True)

# PEAK DET
peaks = signal.find_peaks(scr_chest[1600:2400], height = 0 ,distance=5)


plt.plot(scr_chest[1600:2400], color = 'black', lw = 2, label = 'SCR Raw Data')
plt.ylabel('Hz', fontsize = 25)
plt.yticks(fontsize=20)
plt.xticks(fontsize=20)
plt.legend(prop={'size': 30})

plt.subplot(2, 1, 2)

peaks = signal.find_peaks(scr_chest[1600:2400], height = 0 ,distance=5)
plt.plot(scr_chest[1600:2400], color = 'black', lw = 2, label = 'SCR Data')
plt.scatter(peaks[0], peaks[1]['peak_heights'], color = 'red', s =100, label = 'Peak detected')
plt.yticks(fontsize=20)
plt.xticks(fontsize=20)
plt.ylabel('Hz', fontsize = 25)
plt.grid(True)
plt.legend(prop={'size': 30})
plt.show()
