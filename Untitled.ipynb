# %%
print("hello world")
# Out:
# hello world

# %%
print(12+ 34)
# Out:
# 46

# %%
# %load_ext jupyter_ai_magics
# Out:
# The jupyter_ai_magics extension is already loaded. To reload it, use:
#   %reload_ext jupyter_ai_magics

# %%
# %%ai ollama:gemma3
# Explain quicksort in Python
# Out:
# -----------------------------------------------------------------
# ConnectError                    Traceback (most recent call last)
# File D:\P_DEV\Python313\Lib\site-packages\httpx\_transports\default.py:101, in map_httpcore_exceptions()
#     100 try:
# --> 101     yield
#     102 except Exception as exc:
#
# File D:\P_DEV\Python313\Lib\site-packages\httpx\_transports\default.py:250, in HTTPTransport.handle_request(self, request)
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#
# File D:\P_DEV\Python313\Lib\site-packages\httpcore\_sync\connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#
# ...
